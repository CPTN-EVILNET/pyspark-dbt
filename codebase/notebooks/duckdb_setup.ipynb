# %%
import duckdb

# This will CREATE the DB file automatically
con = duckdb.connect("../duckdb/db.duckdb")

# simple test
con.execute("CREATE TABLE first (id INT, name VARCHAR)")
con.execute("INSERT INTO first VALUES (1, 'A'), (2, 'B')")

print(con.execute("SELECT * FROM first").fetchall())
# Out:
# [(1, 'A'), (2, 'B')]
